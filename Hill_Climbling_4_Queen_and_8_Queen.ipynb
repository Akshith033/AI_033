# %%
import random

N = 4

def calculateCost(state):
    attacking_pairs = 0
    for i in range(N):
        for j in range(i + 1, N):
            if state[i] == state[j] or abs(state[i] - state[j]) == abs(i - j):
                attacking_pairs += 1
    return attacking_pairs

def getNeighbours(state):
    neighbours = []
    for i in range(N):
        for j in range(i + 1, N):
            new_state = state[:]
            new_state[i], new_state[j] = new_state[j], new_state[i]
            neighbours.append(new_state)
    return neighbours

def hillClimbing(initial_state):
    current_state = initial_state
    current_cost = calculateCost(current_state)
    iteration = 0
    while True:
        print(f"\nIteration {iteration}")
        print(f"Current State: {current_state}, Cost: {current_cost}")
        neighbours = getNeighbours(current_state)
        next_state = current_state
        next_cost = current_cost

        for neighbour in neighbours:
            cost = calculateCost(neighbour)
            print(f"Neighbour: {neighbour}, Cost: {cost}")
            if cost < next_cost:
                next_state = neighbour
                next_cost = cost

        if next_cost == current_cost:
            break
        else:
            current_state = next_state
            current_cost = next_cost

        if current_cost == 0:
            break

        iteration += 1

    return current_state, current_cost

def generateRandomState():
    return random.sample(range(N), N)

try:
    user_input = input("Enter initial state as 4 space-separated integers (0 to 3), or press Enter for a random state: ")
    if user_input.strip():
        initial_state = list(map(int, user_input.split()))
    else:
        initial_state = generateRandomState()

    solution_state, solution_cost = hillClimbing(initial_state)

    print("\nFinal Results")
    print("Initial State:", initial_state)
    print("Final State (Solution):", solution_state)
    print("Final Cost (Attacking Pairs):", solution_cost)

    if solution_cost == 0:
        print("Solution found!")
    else:
        print("Local optimum reached, but no solution.")
except KeyboardInterrupt:
    print("\nProgram interrupted by user.")
# Out:
# Enter initial state as 4 space-separated integers (0 to 3), or press Enter for a random state:
#
# Iteration 0
# Current State: [3, 2, 0, 1], Cost: 2
# Neighbour: [2, 3, 0, 1], Cost: 4
# Neighbour: [0, 2, 3, 1], Cost: 1
# Neighbour: [1, 2, 0, 3], Cost: 1
# Neighbour: [3, 0, 2, 1], Cost: 1
# Neighbour: [3, 1, 0, 2], Cost: 1
# Neighbour: [3, 2, 1, 0], Cost: 6
#
# Iteration 1
# Current State: [0, 2, 3, 1], Cost: 1
# Neighbour: [2, 0, 3, 1], Cost: 0
# Neighbour: [3, 2, 0, 1], Cost: 2
# Neighbour: [1, 2, 3, 0], Cost: 4
# Neighbour: [0, 3, 2, 1], Cost: 4
# Neighbour: [0, 1, 3, 2], Cost: 2
# Neighbour: [0, 2, 1, 3], Cost: 2
#
# Final Results
# Initial State: [3, 2, 0, 1]
# Final State (Solution): [2, 0, 3, 1]
# Final Cost (Attacking Pairs): 0
# Solution found!

# %%
import random

N = 4

def calculateCost(state):
    attacking_pairs = 0
    for i in range(N):
        for j in range(i + 1, N):
            if state[i] == state[j] or abs(state[i] - state[j]) == abs(i - j):
                attacking_pairs += 1
    return attacking_pairs

def getNeighbours(state):
    neighbours = []
    for i in range(N):
        for j in range(i + 1, N):
            new_state = state[:]
            new_state[i], new_state[j] = new_state[j], new_state[i]
            neighbours.append(new_state)
    return neighbours

def hillClimbing(initial_state):
    current_state = initial_state
    current_cost = calculateCost(current_state)
    iteration = 0
    while True:
        print(f"\nIteration {iteration}")
        print(f"Current State: {current_state}, Cost: {current_cost}")
        neighbours = getNeighbours(current_state)
        next_state = current_state
        next_cost = current_cost

        for neighbour in neighbours:
            cost = calculateCost(neighbour)
            print(f"Neighbour: {neighbour}, Cost: {cost}")
            if cost < next_cost:
                next_state = neighbour
                next_cost = cost

        if next_cost == current_cost:
            break
        else:
            current_state = next_state
            current_cost = next_cost

        if current_cost == 0:
            break

        iteration += 1

    return current_state, current_cost

def generateRandomState():
    return random.sample(range(N), N)

try:
    user_input = input("Enter initial state as 4 space-separated integers (0 to 3), or press Enter for a random state: ")
    if user_input.strip():
        initial_state = list(map(int, user_input.split()))
    else:
        initial_state = generateRandomState()

    solution_state, solution_cost = hillClimbing(initial_state)

    print("\nFinal Results")
    print("Initial State:", initial_state)
    print("Final State (Solution):", solution_state)
    print("Final Cost (Attacking Pairs):", solution_cost)

    if solution_cost == 0:
        print("Solution found!")
    else:
        print("Local optimum reached, but no solution.")
except KeyboardInterrupt:
    print("\nProgram interrupted by user.")
# Out:
# Enter initial state as 4 space-separated integers (0 to 3), or press Enter for a random state: 0 0 0 0
#
# Iteration 0
# Current State: [0, 0, 0, 0], Cost: 6
# Neighbour: [0, 0, 0, 0], Cost: 6
# Neighbour: [0, 0, 0, 0], Cost: 6
# Neighbour: [0, 0, 0, 0], Cost: 6
# Neighbour: [0, 0, 0, 0], Cost: 6
# Neighbour: [0, 0, 0, 0], Cost: 6
# Neighbour: [0, 0, 0, 0], Cost: 6
#
# Final Results
# Initial State: [0, 0, 0, 0]
# Final State (Solution): [0, 0, 0, 0]
# Final Cost (Attacking Pairs): 6
# Local optimum reached, but no solution.

# %%
import random

N = 8

def calculateCost(state):
    attacking_pairs = 0
    for i in range(N):
        for j in range(i + 1, N):
            if state[i] == state[j] or abs(state[i] - state[j]) == abs(i - j):
                attacking_pairs += 1
    return attacking_pairs

def getNeighbours(state):
    neighbours = []
    for i in range(N):
        for j in range(i + 1, N):
            new_state = state[:]
            new_state[i], new_state[j] = new_state[j], new_state[i]
            neighbours.append(new_state)
    return neighbours

def hillClimbing(initial_state):
    current_state = initial_state
    current_cost = calculateCost(current_state)
    iteration = 0
    while True:
        print(f"\nIteration {iteration}")
        print(f"Current State: {current_state}, Cost: {current_cost}")
        neighbours = getNeighbours(current_state)
        next_state = current_state
        next_cost = current_cost

        for neighbour in neighbours:
            cost = calculateCost(neighbour)
            print(f"Neighbour: {neighbour}, Cost: {cost}")
            if cost < next_cost:
                next_state = neighbour
                next_cost = cost

        if next_cost == current_cost:
            break
        else:
            current_state = next_state
            current_cost = next_cost

        if current_cost == 0:
            break

        iteration += 1

    return current_state, current_cost

def generateRandomState():
    return random.sample(range(N), N)

try:
    user_input = input("Enter initial state as 8 space-separated integers (0 to 7), or press Enter for a random state: ")
    if user_input.strip():
        initial_state = list(map(int, user_input.split()))
    else:
        initial_state = generateRandomState()

    solution_state, solution_cost = hillClimbing(initial_state)

    print("\nFinal Results")
    print("Initial State:", initial_state)
    print("Final State (Solution):", solution_state)
    print("Final Cost (Attacking Pairs):", solution_cost)

    if solution_cost == 0:
        print("Solution found!")
    else:
        print("Local optimum reached, but no solution.")
except KeyboardInterrupt:
    print("\nProgram interrupted by user.")
# Out:
# Enter initial state as 8 space-separated integers (0 to 7), or press Enter for a random state: 0 1 2 7 5 6 4 3
#
# Iteration 0
# Current State: [0, 1, 2, 7, 5, 6, 4, 3], Cost: 7
# Neighbour: [1, 0, 2, 7, 5, 6, 4, 3], Cost: 7
# Neighbour: [2, 1, 0, 7, 5, 6, 4, 3], Cost: 8
# Neighbour: [7, 1, 2, 0, 5, 6, 4, 3], Cost: 3
# Neighbour: [5, 1, 2, 7, 0, 6, 4, 3], Cost: 6
# Neighbour: [6, 1, 2, 7, 5, 0, 4, 3], Cost: 4
# Neighbour: [4, 1, 2, 7, 5, 6, 0, 3], Cost: 5
# Neighbour: [3, 1, 2, 7, 5, 6, 4, 0], Cost: 3
# Neighbour: [0, 2, 1, 7, 5, 6, 4, 3], Cost: 7
# Neighbour: [0, 7, 2, 1, 5, 6, 4, 3], Cost: 5
# Neighbour: [0, 5, 2, 7, 1, 6, 4, 3], Cost: 5
# Neighbour: [0, 6, 2, 7, 5, 1, 4, 3], Cost: 5
# Neighbour: [0, 4, 2, 7, 5, 6, 1, 3], Cost: 3
# Neighbour: [0, 3, 2, 7, 5, 6, 4, 1], Cost: 4
# Neighbour: [0, 1, 7, 2, 5, 6, 4, 3], Cost: 4
# Neighbour: [0, 1, 5, 7, 2, 6, 4, 3], Cost: 5
# Neighbour: [0, 1, 6, 7, 5, 2, 4, 3], Cost: 5
# Neighbour: [0, 1, 4, 7, 5, 6, 2, 3], Cost: 4
# Neighbour: [0, 1, 3, 7, 5, 6, 4, 2], Cost: 6
# Neighbour: [0, 1, 2, 5, 7, 6, 4, 3], Cost: 5
# Neighbour: [0, 1, 2, 6, 5, 7, 4, 3], Cost: 5
# Neighbour: [0, 1, 2, 4, 5, 6, 7, 3], Cost: 9
# Neighbour: [0, 1, 2, 3, 5, 6, 4, 7], Cost: 11
# Neighbour: [0, 1, 2, 7, 6, 5, 4, 3], Cost: 16
# Neighbour: [0, 1, 2, 7, 4, 6, 5, 3], Cost: 8
# Neighbour: [0, 1, 2, 7, 3, 6, 4, 5], Cost: 5
# Neighbour: [0, 1, 2, 7, 5, 4, 6, 3], Cost: 8
# Neighbour: [0, 1, 2, 7, 5, 3, 4, 6], Cost: 5
# Neighbour: [0, 1, 2, 7, 5, 6, 3, 4], Cost: 7
#
# Iteration 1
# Current State: [7, 1, 2, 0, 5, 6, 4, 3], Cost: 3
# Neighbour: [1, 7, 2, 0, 5, 6, 4, 3], Cost: 4
# Neighbour: [2, 1, 7, 0, 5, 6, 4, 3], Cost: 4
# Neighbour: [0, 1, 2, 7, 5, 6, 4, 3], Cost: 7
# Neighbour: [5, 1, 2, 0, 7, 6, 4, 3], Cost: 3
# Neighbour: [6, 1, 2, 0, 5, 7, 4, 3], Cost: 2
# Neighbour: [4, 1, 2, 0, 5, 6, 7, 3], Cost: 5
# Neighbour: [3, 1, 2, 0, 5, 6, 4, 7], Cost: 5
# Neighbour: [7, 2, 1, 0, 5, 6, 4, 3], Cost: 7
# Neighbour: [7, 0, 2, 1, 5, 6, 4, 3], Cost: 4
# Neighbour: [7, 5, 2, 0, 1, 6, 4, 3], Cost: 2
# Neighbour: [7, 6, 2, 0, 5, 1, 4, 3], Cost: 3
# Neighbour: [7, 4, 2, 0, 5, 6, 1, 3], Cost: 2
# Neighbour: [7, 3, 2, 0, 5, 6, 4, 1], Cost: 2
# Neighbour: [7, 1, 0, 2, 5, 6, 4, 3], Cost: 4
# Neighbour: [7, 1, 5, 0, 2, 6, 4, 3], Cost: 3
# Neighbour: [7, 1, 6, 0, 5, 2, 4, 3], Cost: 3
# Neighbour: [7, 1, 4, 0, 5, 6, 2, 3], Cost: 2
# Neighbour: [7, 1, 3, 0, 5, 6, 4, 2], Cost: 4
# Neighbour: [7, 1, 2, 5, 0, 6, 4, 3], Cost: 4
# Neighbour: [7, 1, 2, 6, 5, 0, 4, 3], Cost: 3
# Neighbour: [7, 1, 2, 4, 5, 6, 0, 3], Cost: 5
# Neighbour: [7, 1, 2, 3, 5, 6, 4, 0], Cost: 5
# Neighbour: [7, 1, 2, 0, 6, 5, 4, 3], Cost: 9
# Neighbour: [7, 1, 2, 0, 4, 6, 5, 3], Cost: 4
# Neighbour: [7, 1, 2, 0, 3, 6, 4, 5], Cost: 3
# Neighbour: [7, 1, 2, 0, 5, 4, 6, 3], Cost: 4
# Neighbour: [7, 1, 2, 0, 5, 3, 4, 6], Cost: 2
# Neighbour: [7, 1, 2, 0, 5, 6, 3, 4], Cost: 7
#
# Iteration 2
# Current State: [6, 1, 2, 0, 5, 7, 4, 3], Cost: 2
# Neighbour: [1, 6, 2, 0, 5, 7, 4, 3], Cost: 2
# Neighbour: [2, 1, 6, 0, 5, 7, 4, 3], Cost: 3
# Neighbour: [0, 1, 2, 6, 5, 7, 4, 3], Cost: 5
# Neighbour: [5, 1, 2, 0, 6, 7, 4, 3], Cost: 5
# Neighbour: [7, 1, 2, 0, 5, 6, 4, 3], Cost: 3
# Neighbour: [4, 1, 2, 0, 5, 7, 6, 3], Cost: 5
# Neighbour: [3, 1, 2, 0, 5, 7, 4, 6], Cost: 2
# Neighbour: [6, 2, 1, 0, 5, 7, 4, 3], Cost: 5
# Neighbour: [6, 0, 2, 1, 5, 7, 4, 3], Cost: 3
# Neighbour: [6, 5, 2, 0, 1, 7, 4, 3], Cost: 3
# Neighbour: [6, 7, 2, 0, 5, 1, 4, 3], Cost: 4
# Neighbour: [6, 4, 2, 0, 5, 7, 1, 3], Cost: 0
# Neighbour: [6, 3, 2, 0, 5, 7, 4, 1], Cost: 2
# Neighbour: [6, 1, 0, 2, 5, 7, 4, 3], Cost: 3
# Neighbour: [6, 1, 5, 0, 2, 7, 4, 3], Cost: 3
# Neighbour: [6, 1, 7, 0, 5, 2, 4, 3], Cost: 3
# Neighbour: [6, 1, 4, 0, 5, 7, 2, 3], Cost: 3
# Neighbour: [6, 1, 3, 0, 5, 7, 4, 2], Cost: 2
# Neighbour: [6, 1, 2, 5, 0, 7, 4, 3], Cost: 5
# Neighbour: [6, 1, 2, 7, 5, 0, 4, 3], Cost: 4
# Neighbour: [6, 1, 2, 4, 5, 7, 0, 3], Cost: 3
# Neighbour: [6, 1, 2, 3, 5, 7, 4, 0], Cost: 4
# Neighbour: [6, 1, 2, 0, 7, 5, 4, 3], Cost: 6
# Neighbour: [6, 1, 2, 0, 4, 7, 5, 3], Cost: 3
# Neighbour: [6, 1, 2, 0, 3, 7, 4, 5], Cost: 3
# Neighbour: [6, 1, 2, 0, 5, 4, 7, 3], Cost: 3
# Neighbour: [6, 1, 2, 0, 5, 3, 4, 7], Cost: 4
# Neighbour: [6, 1, 2, 0, 5, 7, 3, 4], Cost: 5
#
# Final Results
# Initial State: [0, 1, 2, 7, 5, 6, 4, 3]
# Final State (Solution): [6, 4, 2, 0, 5, 7, 1, 3]
# Final Cost (Attacking Pairs): 0
# Solution found!

# %%
import random

N = 8

def calculateCost(state):
    attacking_pairs = 0
    for i in range(N):
        for j in range(i + 1, N):
            if state[i] == state[j] or abs(state[i] - state[j]) == abs(i - j):
                attacking_pairs += 1
    return attacking_pairs

def getNeighbours(state):
    neighbours = []
    for i in range(N):
        for j in range(i + 1, N):
            new_state = state[:]
            new_state[i], new_state[j] = new_state[j], new_state[i]
            neighbours.append(new_state)
    return neighbours

def hillClimbing(initial_state):
    current_state = initial_state
    current_cost = calculateCost(current_state)
    iteration = 0
    while True:
        print(f"\nIteration {iteration}")
        print(f"Current State: {current_state}, Cost: {current_cost}")
        neighbours = getNeighbours(current_state)
        next_state = current_state
        next_cost = current_cost

        for neighbour in neighbours:
            cost = calculateCost(neighbour)
            print(f"Neighbour: {neighbour}, Cost: {cost}")
            if cost < next_cost:
                next_state = neighbour
                next_cost = cost

        if next_cost == current_cost:
            break
        else:
            current_state = next_state
            current_cost = next_cost

        if current_cost == 0:
            break

        iteration += 1

    return current_state, current_cost

def generateRandomState():
    return random.sample(range(N), N)

try:
    user_input = input("Enter initial state as 8 space-separated integers (0 to 7), or press Enter for a random state: ")
    if user_input.strip():
        initial_state = list(map(int, user_input.split()))
    else:
        initial_state = generateRandomState()

    solution_state, solution_cost = hillClimbing(initial_state)

    print("\nFinal Results")
    print("Initial State:", initial_state)
    print("Final State (Solution):", solution_state)
    print("Final Cost (Attacking Pairs):", solution_cost)

    if solution_cost == 0:
        print("Solution found!")
    else:
        print("Local optimum reached, but no solution.")
except KeyboardInterrupt:
    print("\nProgram interrupted by user.")
# Out:
# Enter initial state as 8 space-separated integers (0 to 7), or press Enter for a random state:
#
# Iteration 0
# Current State: [2, 5, 6, 0, 1, 4, 7, 3], Cost: 2
# Neighbour: [5, 2, 6, 0, 1, 4, 7, 3], Cost: 4
# Neighbour: [6, 5, 2, 0, 1, 4, 7, 3], Cost: 2
# Neighbour: [0, 5, 6, 2, 1, 4, 7, 3], Cost: 3
# Neighbour: [1, 5, 6, 0, 2, 4, 7, 3], Cost: 3
# Neighbour: [4, 5, 6, 0, 1, 2, 7, 3], Cost: 6
# Neighbour: [7, 5, 6, 0, 1, 4, 2, 3], Cost: 4
# Neighbour: [3, 5, 6, 0, 1, 4, 7, 2], Cost: 4
# Neighbour: [2, 6, 5, 0, 1, 4, 7, 3], Cost: 2
# Neighbour: [2, 0, 6, 5, 1, 4, 7, 3], Cost: 3
# Neighbour: [2, 1, 6, 0, 5, 4, 7, 3], Cost: 3
# Neighbour: [2, 4, 6, 0, 1, 5, 7, 3], Cost: 3
# Neighbour: [2, 7, 6, 0, 1, 4, 5, 3], Cost: 3
# Neighbour: [2, 3, 6, 0, 1, 4, 7, 5], Cost: 2
# Neighbour: [2, 5, 0, 6, 1, 4, 7, 3], Cost: 2
# Neighbour: [2, 5, 1, 0, 6, 4, 7, 3], Cost: 4
# Neighbour: [2, 5, 4, 0, 1, 6, 7, 3], Cost: 4
# Neighbour: [2, 5, 7, 0, 1, 4, 6, 3], Cost: 2
# Neighbour: [2, 5, 3, 0, 1, 4, 7, 6], Cost: 5
# Neighbour: [2, 5, 6, 1, 0, 4, 7, 3], Cost: 3
# Neighbour: [2, 5, 6, 4, 1, 0, 7, 3], Cost: 3
# Neighbour: [2, 5, 6, 7, 1, 4, 0, 3], Cost: 5
# Neighbour: [2, 5, 6, 3, 1, 4, 7, 0], Cost: 2
# Neighbour: [2, 5, 6, 0, 4, 1, 7, 3], Cost: 4
# Neighbour: [2, 5, 6, 0, 7, 4, 1, 3], Cost: 1
# Neighbour: [2, 5, 6, 0, 3, 4, 7, 1], Cost: 3
# Neighbour: [2, 5, 6, 0, 1, 7, 4, 3], Cost: 4
# Neighbour: [2, 5, 6, 0, 1, 3, 7, 4], Cost: 5
# Neighbour: [2, 5, 6, 0, 1, 4, 3, 7], Cost: 5
#
# Iteration 1
# Current State: [2, 5, 6, 0, 7, 4, 1, 3], Cost: 1
# Neighbour: [5, 2, 6, 0, 7, 4, 1, 3], Cost: 1
# Neighbour: [6, 5, 2, 0, 7, 4, 1, 3], Cost: 1
# Neighbour: [0, 5, 6, 2, 7, 4, 1, 3], Cost: 2
# Neighbour: [7, 5, 6, 0, 2, 4, 1, 3], Cost: 3
# Neighbour: [4, 5, 6, 0, 7, 2, 1, 3], Cost: 5
# Neighbour: [1, 5, 6, 0, 7, 4, 2, 3], Cost: 3
# Neighbour: [3, 5, 6, 0, 7, 4, 1, 2], Cost: 5
# Neighbour: [2, 6, 5, 0, 7, 4, 1, 3], Cost: 4
# Neighbour: [2, 0, 6, 5, 7, 4, 1, 3], Cost: 3
# Neighbour: [2, 7, 6, 0, 5, 4, 1, 3], Cost: 2
# Neighbour: [2, 4, 6, 0, 7, 5, 1, 3], Cost: 2
# Neighbour: [2, 1, 6, 0, 7, 4, 5, 3], Cost: 3
# Neighbour: [2, 3, 6, 0, 7, 4, 1, 5], Cost: 1
# Neighbour: [2, 5, 0, 6, 7, 4, 1, 3], Cost: 3
# Neighbour: [2, 5, 7, 0, 6, 4, 1, 3], Cost: 3
# Neighbour: [2, 5, 4, 0, 7, 6, 1, 3], Cost: 3
# Neighbour: [2, 5, 1, 0, 7, 4, 6, 3], Cost: 2
# Neighbour: [2, 5, 3, 0, 7, 4, 1, 6], Cost: 1
# Neighbour: [2, 5, 6, 7, 0, 4, 1, 3], Cost: 5
# Neighbour: [2, 5, 6, 4, 7, 0, 1, 3], Cost: 3
# Neighbour: [2, 5, 6, 1, 7, 4, 0, 3], Cost: 2
# Neighbour: [2, 5, 6, 3, 7, 4, 1, 0], Cost: 3
# Neighbour: [2, 5, 6, 0, 4, 7, 1, 3], Cost: 3
# Neighbour: [2, 5, 6, 0, 1, 4, 7, 3], Cost: 2
# Neighbour: [2, 5, 6, 0, 3, 4, 1, 7], Cost: 3
# Neighbour: [2, 5, 6, 0, 7, 1, 4, 3], Cost: 4
# Neighbour: [2, 5, 6, 0, 7, 3, 1, 4], Cost: 4
# Neighbour: [2, 5, 6, 0, 7, 4, 3, 1], Cost: 4
#
# Final Results
# Initial State: [2, 5, 6, 0, 1, 4, 7, 3]
# Final State (Solution): [2, 5, 6, 0, 7, 4, 1, 3]
# Final Cost (Attacking Pairs): 1
# Local optimum reached, but no solution.
